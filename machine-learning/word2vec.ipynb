# %% [markdown]
# # Table of Contents
#  <p>

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import random
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange  # pylint: disable=redefined-builtin
import tensorflow as tf

# %%
# Step 1: Download the data.
url = 'http://mattmahoney.net/dc/'


def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urllib.request.urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified', filename)
  else:
    print(statinfo.st_size)
    raise Exception(
        'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %%
# Read the data into a list of strings.
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words."""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data

vocabulary = read_data(filename)
print('Data size', len(vocabulary))
# Out:
# Data size 17005207

# %%
# Step 2: Build the dictionary and replace rare words with UNK token.
vocabulary_size = 50000

def build_dataset(words, n_words):
    """process raw inputs into a dataset"""
    count = [['UNK', -1]]
    # count occurence
    count.extend(collections.Counter(words).most_common(n_words - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0 # dictionary ['UNK']
            unk_count += 1
        data.append(index)
    count[0][1] = unk_count
    reversed_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reversed_dictionary
    
# data : 単語のリストをidで置き換えたもの
data, count, dictionary, reverse_dictionary = build_dataset(vocabulary, vocabulary_size)

del vocabulary # Hint to reduce memory.
print('Most common word (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])
# Out:
# Most common word (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5242, 3084, 12, 6, 195, 2, 3135, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %% [markdown]
# eatを中心としたウィンドウ
#
# I [want to eat an apple] everyday
#
# * buffer : 切り取られたウィンドウ dequeでつくっているので、appendすると頭がずれる
# * skip_window : 両脇の単語数 2
# * span : ウィンドウ全体の長さ
# * ウィンドウの中からランダムにひとつ単語をとってきて、eatとペアをつくる
# * num_skips : １つのウィンドウの中で何個ペアをつくるか。2 * skip_windowにすれば、全部のペアがつくられる。

# %%
data_index = 0
# Step 3: Function to generate a training batch for the skip-gram model.
def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window]
    buffer = collections.deque(maxlen=span) # deque : list-like container with fast push pop
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window # target label at the centerr of the buffer
        targets_to_avoid = [skip_window]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    # Backtrack a little bit to avoid skipping words in the end of a batch
    data_index = (data_index + len(data) - span) % len(data)
    return batch, labels
        
batch, labels = generate_batch(batch_size=12, num_skips=2, skip_window=3)
for i in range(8):
    print(batch[i], reverse_dictionary[batch[i]], '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
    
print(batch)
print(labels)
# Out:
# 6 a -> 3084 originated
# 6 a -> 5242 anarchism
# 195 term -> 6 a
# 195 term -> 46 first
# 2 of -> 59 used
# 2 of -> 6 a
# 3135 abuse -> 59 used
# 3135 abuse -> 2 of
# [   6    6  195  195    2    2 3135 3135   46   46   59   59]
# [[3084]
#  [5242]
#  [   6]
#  [  46]
#  [  59]
#  [   6]
#  [  59]
#  [   2]
#  [   2]
#  [ 156]
#  [ 128]
#  [  46]]

# %% [markdown]
# [参考](http://qiita.com/Hironsan/items/11b388575a058dc8a46a)
# 隠れ層の前後の結合は同じ行列を使う

# %% [markdown]
# Noise-Contrastive Estimation
#
# 全部のボキャブラリーに対する確率を計算するのは大変→ランダムに取り出したk個の単語の確率を低くするような学習をする

# %%
# Step 4: Build and train a skip-gram model.
batch_size = 128
embedding_size = 128 # dimension of the embedding vector
skip_window = 1 # how many words to consider left and right
num_skips = 2 # how many times to reuse an input to generate a label

# We pick a random validation set to sample nearest neighbors. Here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16     # Random set of words to evaluate similarity on.
valid_window = 100  # Only pick dev samples in the head of the distribution.
valid_examples = np.random.choice(valid_window, valid_size, replace=False)
num_sampled = 64    # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():
    # Input data
    train_inputs = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # Ops and variables pinned to the CPU because of missing GPU implementation
    with tf.device('/cpu:0'):
        # Look up embeddings for inputs
        embeddings = tf.Variable(
            tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
        # train_inputsをいれるとembeddingsの対応するものを返す
        embed= tf.nn.embedding_lookup(embeddings, train_inputs)
        
        # Construct the variables for the NCE loss
        nce_weights = tf.Variable(
            tf.truncated_normal([vocabulary_size, embedding_size], 
                                stddev=1.0 / math.sqrt(embedding_size)))
        nce_biases = tf.Variable(tf.zeros([vocabulary_size]))
        
        # Compute the average NCE loss for the batch
        # tf.nce_loss automatically draws a new sample of the negative labes each
        # time we evaluate the loss
        loss  = tf.reduce_mean(
            tf.nn.nce_loss(
                weights=nce_weights,
                biases=nce_biases,
                labels=train_labels,
                inputs=embed,
                num_sampled=num_sampled,
                num_classes=vocabulary_size
            ))
        
        # Construct the SGD optimizer using a learning rate of 1.0
        optimizer = tf.train.GradientDescentOptimizer(1.0).minimize(loss)
        
        # Compute the cosine similarity between minibatch examples and all embeddings.
        norm  = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
        normalized_embeddings = embeddings / norm
        valid_embeddings = tf.nn.embedding_lookup(
            normalized_embeddings, valid_dataset)
        similarity = tf.matmul(
            valid_embeddings, normalized_embeddings, transpose_b=True)
        
        # Add variable initializer
        init = tf.initialize_all_variables()

# %%
# Step 5 : Begin training
num_steps = 100001
with tf.Session(graph=graph) as session:
    #  We must initialize all variables before use them
    init.run()
    print('Initialized')
    
    average_loss = 0
    for step in xrange(num_steps):
        batch_inputs, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        feed_dict = {train_inputs: batch_inputs, train_labels:batch_labels}
        
        # We perform one update step by evaluating the optimizer op (including it
        # in the list of returned values for session.run()
        _, loss_val = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += loss_val
        
        if step % 2000 == 0:
            if step > 0:
                average_loss /= 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step ', step, ': ', average_loss)
            average_loss = 0 
        # Note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in xrange(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8  # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                log_str = 'Nearest to %s:' % valid_word
                for k in xrange(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log_str = '%s %s,' % (log_str, close_word)
                print(log_str)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step  0 :  249.44442749
# Nearest to world: tolls, positivist, befall, ronstadt, teleport, attenuated, salaam, unwin,
# Nearest to years: rambling, fianc, montt, gonzo, embodying, strau, axillary, vlaams,
# Nearest to all: presbyters, comedienne, even, jensen, quitting, fijians, flaps, avery,
# Nearest to in: walther, heaped, kumquat, warts, haute, symbolizing, incorporating, jumbled,
# Nearest to no: electrochemistry, whitehouse, tides, proofs, approves, massawa, kinetoscope, aap,
# Nearest to see: excommunicate, gangsta, ghb, southwards, westward, studd, cecilia, wilfrid,
# Nearest to new: keep, conservatorium, chairperson, messengers, ethane, massawa, bengals, prosecutors,
# Nearest to from: prototypical, jasmuheen, ibu, mullin, submersible, reorganize, soufriere, glennon,
# Nearest to he: oboe, impairments, actors, dreamland, joram, gorey, bevel, purchase,
# Nearest to of: aotearoa, infrastructure, dreidel, rebuke, transgendered, risk, hogshead, ponte,
# Nearest to known: abolish, tributaries, hydroponic, bambara, nest, invariance, runs, commandants,
# Nearest to there: rf, maa, mjw, propriety, kareem, dougherty, semiarid, cga,
# Nearest to only: edouard, mindful, readers, homerun, plugs, einhard, lanier, enforced,
# Nearest to which: rivaled, balkan, thousandth, chancellorsville, divides, muddy, landing, immerse,
# Nearest to people: liu, fpss, uc, bandy, exclusive, kou, fortress, spector,
# Nearest to over: encamped, charon, redness, cert, didactic, tgs, kane, keratin,
# Average loss at step  2000 :  114.344450709
# Average loss at step  4000 :  51.8676209841
# Average loss at step  6000 :  33.0786959493
# Average loss at step  8000 :  23.5912854629
# Average loss at step  10000 :  17.8362542691
# Nearest to world: following, stout, coloring, agave, archie, horse, spelling, bckgr,
# Nearest to years: cc, ba, entries, agave, months, zero, backward, required,
# Nearest to all: even, fao, UNK, flat, sx, progress, restored, anchorage,
# Nearest to in: and, of, with, on, archie, by, gb, to,
# Nearest to no: miscible, bureau, tides, x, den, lake, nine, agave,
# Nearest to see: studd, compensate, secular, gangsta, lymphoma, characterised, abolition, memory,
# Nearest to new: keep, and, disease, trial, ethane, produce, gb, toledo,
# Nearest to from: in, by, dislike, zero, of, and, immediately, retreated,
# Nearest to he: it, and, impairments, parties, increased, ivan, exactly, fins,
# Nearest to of: and, in, for, rotate, archie, with, at, gb,
# Nearest to known: listed, relativity, abolish, drawing, agave, runs, cosmonaut, criticized,
# Nearest to there: which, rf, genital, bckgr, proposal, alkanes, legally, verlag,
# Nearest to only: edouard, readers, lymphoma, mysore, archie, rarely, UNK, mathbf,
# Nearest to which: balkan, and, there, sigma, negotiations, that, mosque, landing,
# Nearest to people: fortress, spectrum, win, uc, youth, mere, exclusive, dull,
# Nearest to over: archie, encamped, fao, marple, kane, reserves, lack, gastrointestinal,
# Average loss at step  12000 :  13.9739590689
# Average loss at step  14000 :  11.8449859113
# Average loss at step  16000 :  10.0709388574
# Average loss at step  18000 :  8.55948849708
# Average loss at step  20000 :  7.95083431983
# Nearest to world: following, operatorname, coloring, aurelian, stout, horse, fuelled, archie,
# Nearest to years: gollancz, cc, months, friars, dasyprocta, five, zero, backward,
# Nearest to all: apatosaurus, jensen, even, agouti, circ, fao, flat, restored,
# Nearest to in: and, of, from, on, for, at, with, archie,
# Nearest to no: bureau, den, archive, miscible, tides, disparity, lake, declines,
# Nearest to see: compensate, studd, of, designer, breach, abolition, southwards, characterised,
# Nearest to new: keep, trial, sins, toledo, disease, and, pieter, lothar,
# Nearest to from: in, by, and, onyx, of, to, dislike, dasyprocta,
# Nearest to he: it, they, and, ivan, there, who, apatosaurus, impairments,
# Nearest to of: and, in, for, agouti, nine, dasyprocta, archie, zero,
# Nearest to known: a, listed, fisher, diss, remini, cosmonaut, relativity, drawing,
# Nearest to there: which, it, they, he, rf, gum, this, and,
# Nearest to only: operatorname, readers, edouard, einhard, circ, mysore, lymphoma, string,
# Nearest to which: that, apatosaurus, and, there, balkan, sigma, it, this,
# Nearest to people: fortress, uc, dasyprocta, agouti, circ, liu, exclusive, spector,
# Nearest to over: charon, agouti, encamped, in, gastrointestinal, archie, hostages, trapezohedron,
# Average loss at step  22000 :  7.02842688537
# Average loss at step  24000 :  6.94121478355
# Average loss at step  26000 :  6.76935922229
# Average loss at step  28000 :  6.36186869502
# Average loss at step  30000 :  5.91176715231
# Nearest to world: following, bcl, operatorname, tolls, coloring, abet, stout, aurelian,
# Nearest to years: gollancz, months, cc, christened, friars, liverpool, therapist, dynamically,
# Nearest to all: apatosaurus, comedienne, jensen, agouti, circ, fao, even, operatorname,
# Nearest to in: on, from, at, with, and, by, for, archie,
# Nearest to no: bureau, castillo, den, declines, nine, disparity, archive, lake,
# Nearest to see: compensate, abolition, studd, designer, breach, renounce, four, creates,
# Nearest to new: keep, mishnayot, and, bengals, toledo, trial, sins, messengers,
# Nearest to from: in, by, onyx, of, with, to, under, for,
# Nearest to he: it, they, there, who, we, she, ivan, zero,
# Nearest to of: and, for, in, with, eight, abakan, from, dasyprocta,
# Nearest to known: listed, a, fisher, used, remini, cosmonaut, dasyprocta, abakan,
# Nearest to there: which, it, they, he, this, rf, also, propriety,
# Nearest to only: operatorname, readers, edouard, einhard, circ, apatosaurus, it, string,
# Nearest to which: that, apatosaurus, there, this, it, and, also, sigma,
# Nearest to people: refractive, fortress, uc, agouti, spector, liu, exclusive, dasyprocta,
# Nearest to over: in, charon, agouti, encamped, hostages, linen, gastrointestinal, jazeera,
# Average loss at step  32000 :  5.91993697745
# Average loss at step  34000 :  5.68748651898
# Average loss at step  36000 :  5.75819701278
# Average loss at step  38000 :  5.53641242254
# Average loss at step  40000 :  5.27057194054
# Nearest to world: bcl, following, operatorname, tolls, fuelled, abet, coloring, stout,
# Nearest to years: gollancz, months, cc, five, eight, friars, four, zero,
# Nearest to all: jensen, apatosaurus, agouti, comedienne, many, circ, anacharsis, some,
# Nearest to in: on, and, archie, at, from, operatorname, agouti, with,
# Nearest to no: bureau, castillo, declines, a, disparity, tides, kampen, den,
# Nearest to see: compensate, abolition, designer, studd, dimethyl, quaternary, renounce, four,
# Nearest to new: mishnayot, keep, sidearm, major, bengals, agouti, toledo, hakama,
# Nearest to from: in, by, under, with, onyx, and, dasyprocta, circ,
# Nearest to he: it, they, she, who, there, which, we, zero,
# Nearest to of: in, zero, for, and, agouti, abakan, dasyprocta, nine,
# Nearest to known: multivibrator, listed, used, fisher, abolition, cosmonaut, remini, a,
# Nearest to there: which, it, they, he, rf, lugs, also, not,
# Nearest to only: operatorname, readers, edouard, it, string, circ, einhard, apatosaurus,
# Nearest to which: that, apatosaurus, it, there, this, also, and, who,
# Nearest to people: uc, refractive, fortress, spector, agouti, liu, principally, cafe,
# Nearest to over: agouti, charon, encamped, linen, hostages, gastrointestinal, jazeera, trapezohedron,
# Average loss at step  42000 :  5.39258098483
# Average loss at step  44000 :  5.22361135709
# Average loss at step  46000 :  5.20572676301
# Average loss at step  48000 :  5.26393744504
# Average loss at step  50000 :  5.00067811811
# Nearest to world: bcl, following, operatorname, tolls, fuelled, abet, stout, kapoor,
# Nearest to years: months, gollancz, fianc, cc, four, shaken, friars, five,
# Nearest to all: many, agouti, apatosaurus, mukherjee, jensen, circ, comedienne, anacharsis,
# Nearest to in: on, at, from, for, archie, between, with, operatorname,
# Nearest to no: castillo, bureau, declines, disparity, admissions, kampen, tides, phi,
# Nearest to see: cuckoo, compensate, creates, lamanites, abolition, renounce, quaternary, dimethyl,
# Nearest to new: mishnayot, major, sidearm, kapoor, keep, sins, bengals, vladimir,
# Nearest to from: in, by, and, with, under, of, eight, at,
# Nearest to he: it, they, she, who, there, we, roshan, kapoor,
# Nearest to of: in, for, marek, and, nine, dasyprocta, archie, eight,
# Nearest to known: multivibrator, listed, used, fisher, glamour, a, abolition, cosmonaut,
# Nearest to there: which, it, they, he, rf, this, also, lugs,
# Nearest to only: operatorname, readers, circ, apatosaurus, string, it, einhard, kapoor,
# Nearest to which: that, this, apatosaurus, it, there, also, and, mishnayot,
# Nearest to people: uc, refractive, agouti, fortress, spector, dasyprocta, cafe, throat,
# Nearest to over: agouti, charon, encamped, kapoor, seven, linen, hostages, trapezohedron,
# Average loss at step  52000 :  5.03373825681
# Average loss at step  54000 :  5.19128970981
# Average loss at step  56000 :  5.03180397785
# Average loss at step  58000 :  5.04372789252
# Average loss at step  60000 :  4.92553260708
# Nearest to world: bcl, following, tolls, fuelled, abet, operatorname, kapoor, positivist,
# Nearest to years: months, wct, gollancz, fianc, four, phonation, cc, shaken,
# Nearest to all: many, some, agouti, apatosaurus, mukherjee, any, jensen, circ,
# Nearest to in: on, and, at, from, archie, between, during, gigantopithecus,
# Nearest to no: bureau, castillo, thibetanus, nine, admissions, disparity, declines, excalibur,
# Nearest to see: btu, creates, of, cuckoo, and, quaternary, compensate, manoeuvres,
# Nearest to new: ursus, mishnayot, major, sidearm, kapoor, sins, vladimir, hadadezer,
# Nearest to from: in, under, at, onyx, and, eight, by, nine,
# Nearest to he: it, she, they, who, there, we, roshan, kapoor,
# Nearest to of: and, nine, in, ursus, for, pulau, abakan, six,
# Nearest to known: used, multivibrator, listed, such, fisher, glamour, well, cosmonaut,
# Nearest to there: it, they, which, he, this, usually, rf, who,
# Nearest to only: operatorname, circ, readers, wct, apatosaurus, string, einhard, ursus,
# Nearest to which: that, this, apatosaurus, it, also, there, who, but,
# Nearest to people: agouti, uc, refractive, dasyprocta, fortress, spector, cafe, throat,
# Nearest to over: agouti, linen, charon, encamped, kapoor, gastrointestinal, ez, moonlight,
# Average loss at step  62000 :  4.99119462073
# Average loss at step  64000 :  4.83422471255
# Average loss at step  66000 :  4.5998142283
# Average loss at step  68000 :  4.98225869203
# Average loss at step  70000 :  4.87548696542
# Nearest to world: bcl, tolls, microcebus, fuelled, following, positivist, abet, kapoor,
# Nearest to years: months, wct, gollancz, four, fianc, six, phonation, five,
# Nearest to all: many, some, mitral, any, agouti, mukherjee, these, apatosaurus,
# Nearest to in: at, on, and, from, thaler, archie, operatorname, gigantopithecus,
# Nearest to no: bureau, castillo, little, admissions, thibetanus, disparity, together, oratory,
# Nearest to see: creates, btu, and, can, quaternary, cuckoo, of, manoeuvres,
# Nearest to new: ursus, mishnayot, major, sidearm, pact, kapoor, pulau, bengals,
# Nearest to from: in, under, by, onyx, thaler, mullin, dasyprocta, eight,
# Nearest to he: it, she, they, who, there, we, stative, thaler,
# Nearest to of: and, abakan, ursus, for, microcebus, in, marek, archie,
# Nearest to known: used, listed, multivibrator, such, well, fisher, cosmonaut, glamour,
# Nearest to there: it, they, which, he, this, usually, now, often,
# Nearest to only: operatorname, circ, thaler, apatosaurus, wct, readers, ursus, einhard,
# Nearest to which: that, this, apatosaurus, also, it, there, but, mishnayot,
# Nearest to people: uc, agouti, dasyprocta, refractive, spector, upanija, cafe, fortress,
# Nearest to over: agouti, callithrix, linen, gastrointestinal, caryophyllales, charon, sindh, kapoor,
# Average loss at step  72000 :  4.74531688792
# Average loss at step  74000 :  4.79341794837
# Average loss at step  76000 :  4.72818663752
# Average loss at step  78000 :  4.81585587326
# Average loss at step  80000 :  4.81896578825
# Nearest to world: positivist, bcl, tolls, following, fuelled, abet, microcebus, kapoor,
# Nearest to years: months, wct, gollancz, fianc, phonation, leontopithecus, shaken, christened,
# Nearest to all: many, some, any, mitral, these, mukherjee, agouti, apatosaurus,
# Nearest to in: archie, at, on, and, thaler, from, of, during,
# Nearest to no: castillo, bureau, little, oratory, disparity, admissions, excalibur, there,
# Nearest to see: creates, btu, haznawi, quaternary, cuckoo, can, microcebus, vip,
# Nearest to new: ursus, mishnayot, major, sidearm, pact, kapoor, sins, operatorname,
# Nearest to from: in, under, by, onyx, into, through, and, at,
# Nearest to he: it, she, they, who, there, thaler, we, stative,
# Nearest to of: in, microcebus, including, marek, ursus, dasyprocta, for, agouti,
# Nearest to known: used, listed, such, multivibrator, well, cosmonaut, criticized, fisher,
# Nearest to there: it, they, which, he, now, usually, this, often,
# Nearest to only: operatorname, circ, apatosaurus, wct, thaler, ursus, string, readers,
# Nearest to which: that, this, apatosaurus, it, also, there, but, what,
# Nearest to people: uc, agouti, spector, refractive, others, dasyprocta, fortress, cafe,
# Nearest to over: agouti, callithrix, linen, gastrointestinal, kapoor, caryophyllales, thaler, sindh,
# Average loss at step  82000 :  4.77988631701
# Average loss at step  84000 :  4.74873408496
# Average loss at step  86000 :  4.76389881611
# Average loss at step  88000 :  4.74142785287
# Average loss at step  90000 :  4.72003822696
# Nearest to world: bcl, positivist, tolls, fugitives, game, fuelled, abet, microcebus,
# Nearest to years: months, wct, gollancz, fianc, phonation, leontopithecus, peacocks, houser,
# Nearest to all: many, some, these, any, mitral, mukherjee, agouti, callithrix,
# Nearest to in: on, at, during, archie, thaler, from, gigantopithecus, and,
# Nearest to no: bureau, little, castillo, admissions, thibetanus, disparity, oratory, together,
# Nearest to see: and, btu, creates, quaternary, haznawi, can, cuckoo, microcebus,
# Nearest to new: ursus, mishnayot, major, kapoor, sidearm, agouti, operatorname, pulau,
# Nearest to from: in, under, onyx, by, into, circ, at, during,
# Nearest to he: it, she, they, who, there, we, stative, thaler,
# Nearest to of: including, in, ursus, for, and, abakan, marek, eight,
# Nearest to known: used, listed, such, well, multivibrator, recognized, criticized, glamour,
# Nearest to there: they, it, he, which, now, usually, this, often,
# Nearest to only: operatorname, apatosaurus, circ, wct, thaler, ursus, adamantium, archie,
# Nearest to which: that, this, apatosaurus, it, also, but, what, who,
# Nearest to people: uc, others, agouti, spector, refractive, those, animals, cafe,
# Nearest to over: agouti, callithrix, linen, gastrointestinal, caryophyllales, thaler, kapoor, sindh,
# Average loss at step  92000 :  4.66326560938
# Average loss at step  94000 :  4.71903986943
# Average loss at step  96000 :  4.70495414376
# Average loss at step  98000 :  4.5849096384
# Average loss at step  100000 :  4.70608605683
# Nearest to world: positivist, bcl, abet, microcebus, fugitives, tolls, fuelled, kapoor,
# Nearest to years: months, wct, fianc, gollancz, four, houser, peacocks, phonation,
# Nearest to all: many, some, any, these, mitral, mukherjee, agouti, callithrix,
# Nearest to in: at, during, on, archie, thaler, under, operatorname, gigantopithecus,
# Nearest to no: little, castillo, bureau, nine, admissions, thibetanus, disparity, oratory,
# Nearest to see: creates, haznawi, btu, microcebus, and, quaternary, can, cuckoo,
# Nearest to new: mishnayot, ursus, major, sidearm, sins, kapoor, vladimir, acrylic,
# Nearest to from: in, under, into, onyx, at, circ, dasyprocta, thaler,
# Nearest to he: it, she, they, there, who, thaler, we, stative,
# Nearest to of: in, ursus, including, marek, abakan, dasyprocta, for, microcebus,
# Nearest to known: used, such, listed, well, criticized, abolition, recognized, multivibrator,
# Nearest to there: it, they, he, which, now, usually, this, but,
# Nearest to only: operatorname, apatosaurus, circ, thaler, ursus, wct, adamantium, archie,
# Nearest to which: that, this, apatosaurus, also, it, but, what, there,
# Nearest to people: agouti, uc, others, spector, dasyprocta, those, refractive, upanija,
# Nearest to over: agouti, callithrix, linen, thaler, kapoor, gastrointestinal, caryophyllales, about,

# %%
# Step 6: Visualize the embeddings.
def plot_with_labels(low_dim_embs, labels, filename='tsne.png'):
    assert low_dim_embs.shape[0] >= len(labels), 'More labels than embeddings'
    plt.figure(figsize=(18, 18))  # in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i, :]
        plt.scatter(x, y)
        plt.annotate(label,
                 xy=(x, y),
                 xytext=(5, 2),
                 textcoords='offset points',
                 ha='right',
                 va='bottom')

    plt.savefig(filename)

try:
    # pylint: disable=g-import-not-at-top
    from sklearn.manifold import TSNE
    import matplotlib.pyplot as plt
    tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
    plot_only = 500
    low_dim_embs = tsne.fit_transform(final_embeddings[:plot_only, :])
    labels = [reverse_dictionary[i] for i in xrange(plot_only)]
    plot_with_labels(low_dim_embs, labels)

except ImportError:
    print('Please install sklearn, matplotlib, and scipy to show embeddings.')
# Out:
# /Users/kazumasa/.pyenv/versions/anaconda3-2.4.0/lib/python3.5/site-packages/sklearn/utils/fixes.py:64: DeprecationWarning: inspect.getargspec() is deprecated, use inspect.signature() instead
#   if 'order' in inspect.getargspec(np.copy)[0]:
